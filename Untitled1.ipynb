# %%
import joblib 
my_model= joblib.load("my_model.pkl")

# %%
my_model.predict([[20000]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 my_model.predict([[20000]])
#
# File ~/Desktop/ML/ml_env/lib/python3.13/site-packages/sklearn/ensemble/_forest.py:1065, in ForestRegressor.predict(self, X)
#    1063 check_is_fitted(self)
#    1064 # Check data
# -> 1065 X = self._validate_X_predict(X)
#    1067 # Assign chunk of trees to jobs
#    1068 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~/Desktop/ML/ml_env/lib/python3.13/site-packages/sklearn/ensemble/_forest.py:637, in BaseForest._validate_X_predict(self, X)
#     634 else:
#     635     ensure_all_finite = True
# --> 637 X = validate_data(
#     638     self,
#     639     X,
#     640     dtype=DTYPE,
#     641     accept_sparse="csr",
#     642     reset=False,
#     643     ensure_all_finite=ensure_all_finite,
#     644 )
# ...
